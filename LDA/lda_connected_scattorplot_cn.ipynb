# %%
import numpy as np
import pandas as pd
import os

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from scipy.special import rel_entr
from scipy.stats import entropy
import scipy.stats
import math
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# # 資料表公司合併

# %%
for i in range(2015,2020):
    us = pd.read_csv("competitor_df/company/lda_cn_{}.csv".format(i))
    us_a = pd.read_csv("competitor_df/company/lda_cn_{}.csv".format(i+1))
    
    us.rename(columns = {'cpc':'cpc_{}'.format(i), 'country':'country_{}'.format(i)}, inplace = True)
    us_a.rename(columns = {'cpc':'cpc_{}'.format(i+1), 'country':'country_{}'.format(i+1)}, inplace = True)
    
    if i != 2015:
        us_all = pd.merge(us_all,us_a, on=['company'],how='outer')
    else:
        us_all = pd.merge(us,us_a, on=['company'],how='outer')

# %%
us_all
# Out:
#                                           company  cpc_2015  country_2015  \
# 0                                    Qinchuan_IoT  0.263722      0.610376
# 1                               SUZHOU_XUANHE_IOT  0.284004      0.616430
# 2                                     Jiangsu_IoT  0.205741      0.543976
# 3                                    Hansense_IOT  0.066021      0.413306
# 4                                     Nanjing_IoT  0.142798      0.410445
# 5                                        ABEJ_IOT  0.069526      0.407761
# 6                             Huawei Technologies  0.059937      0.265119
# 7                                  QIANHAI_LINGJU  0.073860      0.364882
# 8                                          Livall  0.073860      0.364882
# 9                                           THZST  0.111214      0.398469
# 10                                       Mangoiot  0.024401      0.400452
# 11                            Chongqing_Liuhe_IOT  0.024401      0.400452
# 12                              Huizhou_Sanhe_IOT  0.087925      0.403536
# 13                                    Xian_Iraine  0.045232      0.407977
# 14                                            ZTE       NaN           NaN
# 15                              Anhui_Sharetronic       NaN           NaN
# 16                                Shanghai_Langbo       NaN           NaN
# 17                                   China_Mobile       NaN           NaN
# 18                             JBT_Smart_Lighting       NaN           NaN
# 19                              Mayixiongbing_IoT       NaN           NaN
# 20                                        Shenglu       NaN           NaN
# 21                                       Qualcomm       NaN           NaN
# 22                                       Wopu_IoT       NaN           NaN
# 23                                       Ericsson       NaN           NaN
# 24                 Fujian Strong Min Mdt Infotech       NaN           NaN
# 25                                     Huaway_IoT       NaN           NaN
# 26                                          Intel       NaN           NaN
# 27                            HUIZHOU_TECHZEN_IOT       NaN           NaN
# 28                                     NTT Docomo       NaN           NaN
# 29                                      NTT Korea       NaN           NaN
# 30                                           Oppo       NaN           NaN
# 31                                          Apple       NaN           NaN
# 32                                 LG Electronics       NaN           NaN
# 33                                            CUG       NaN           NaN
# 34       Guangdong Oppo Mobile Telecommunications       NaN           NaN
# 35                               China_Mobile_IoT       NaN           NaN
# 36                                        Neusoft       NaN           NaN
# 37                          Alibaba Group Holding       NaN           NaN
# 38                                   China_Unicom       NaN           NaN
# 39  Shanghai Roye Electric Science and Technology       NaN           NaN
# 40              Xian Irain IoT Technology Service       NaN           NaN
# 41                                           SGCC       NaN           NaN
# 42                                Beijing_Sankuai       NaN           NaN
# 43                    Tencent Technology Shenzhen       NaN           NaN
# 44         Alipay Hangzhou Information Technology       NaN           NaN
# 45                                         Xiaomi       NaN           NaN
#
#     cpc_2016  country_2016  cpc_2017  country_2017  cpc_2018  country_2018  \
# 6   0.446272      0.436963  0.366366      0.445048
# 7        NaN           NaN       NaN           NaN
# 8        NaN           NaN       NaN           NaN
# 9        NaN           NaN       NaN           NaN
# 10       NaN           NaN       NaN           NaN
# 11       NaN           NaN       NaN           NaN
# 12       NaN           NaN       NaN           NaN
# 13       NaN           NaN       NaN           NaN
# 14       NaN           NaN       NaN           NaN
# 15       NaN           NaN       NaN           NaN
# 16  0.369364      0.315554  0.054253      0.323479
# 17  0.121547      0.325525  0.112161      0.354690
# 18       NaN           NaN       NaN           NaN
# 19       NaN           NaN       NaN           NaN
# 20       NaN           NaN       NaN           NaN
# 21       NaN           NaN       NaN           NaN
# 22       NaN           NaN       NaN           NaN
# 23  0.355618      0.241392  0.374251      0.295468
# 24       NaN           NaN       NaN           NaN
# 25       NaN           NaN       NaN           NaN
# 26       NaN           NaN  0.190969      0.205354
# 27       NaN           NaN       NaN           NaN
# 28  0.367843      0.204662       NaN           NaN
# 29       NaN           NaN       NaN           NaN
# 30       NaN           NaN       NaN           NaN
# 31  0.421551      0.365900  0.338637      0.297559
# 32       NaN           NaN  0.368683      0.297376
# 33       NaN           NaN       NaN           NaN
# 34  0.342307      0.194833       NaN           NaN
# 35  0.072141      0.340974  0.130255      0.398382
# 36  0.173321      0.347429       NaN           NaN
# 37  0.174563      0.346286       NaN           NaN
# 38  0.241279      0.365361  0.289351      0.344300
# 39  0.076595      0.381658       NaN           NaN
# 40  0.274220      0.387274       NaN           NaN
# 41  0.158551      0.415397  0.093928      0.357953
# 42       NaN           NaN  0.122535      0.376978
# 43       NaN           NaN  0.157797      0.379621
# 44       NaN           NaN  0.176692      0.410007
# 45       NaN           NaN  0.385715      0.414283

# %%
cpc_ls = list(-us_all[us_all.company=="Huawei Technologies"].iloc[:,[1,3,5,7,9,11]].values[0])
country_ls = list(-us_all[us_all.company=="Huawei Technologies"].iloc[:,[2,4,6,8,10,12]].values[0])
year = list(range(2015,2021))

# %%
df = pd.DataFrame((zip(year, cpc_ls, country_ls)), columns = ['year','cpc', 'country'])

# %%
df
# Out:
#    year       cpc   country
# 0  2015 -0.059937 -0.265119
# 1  2016 -0.331416 -0.379693
# 2  2017 -0.220577 -0.220966
# 3  2018 -0.217858 -0.223773
# 4  2019 -0.446272 -0.436963
# 5  2020 -0.366366 -0.445048

# %% [markdown]
# # Scatter plot

# %%
plt.figure(figsize=(6,6))
plt.style.use('ggplot')

plt.plot("cpc", "country", data=df, linestyle='-', marker='o')
# plt.scatter(-c_df.cpc, -c_df.country, alpha=0.5)


plt.title("CNIPA \n - Huawei Technologies")
plt.xlabel("LDA similarity")
plt.ylabel("Patent Family")


for i, txt in enumerate(df.year):
    plt.text(df.cpc[i]+0.0015, df.country[i],txt)



plt.show()

# %%
for i, txt in enumerate(df.year):
    print(df.cpc[i])
    # plt.text(-df.cpc[i], -df.country[i],txt.split(" ")[0])
# Out:
# -0.0600411409029895
# -0.1676614499104834
# -0.0711309410060329
# -0.0722114279759647
# -0.1254459754914161
# -0.0768850589582878
