# %%
import numpy as np
import pandas as pd
import os

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from scipy.special import rel_entr
from scipy.stats import entropy
import scipy.stats
import math
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# # 資料表公司合併

# %%
for i in range(2015,2020):
    us = pd.read_csv("competitor_df/company/lda_us_{}.csv".format(i))
    us_a = pd.read_csv("competitor_df/company/lda_us_{}.csv".format(i+1))
    
    us.rename(columns = {'cpc':'cpc_{}'.format(i), 'country':'country_{}'.format(i)}, inplace = True)
    us_a.rename(columns = {'cpc':'cpc_{}'.format(i+1), 'country':'country_{}'.format(i+1)}, inplace = True)
    
    if i != 2015:
        us_all = pd.merge(us_all,us_a, on=['company'],how='outer')
    else:
        us_all = pd.merge(us,us_a, on=['company'],how='outer')

# %%
us_all
# Out:
#                                               company  cpc_2015  country_2015  \
# 0                                               Intel  0.060041      0.225982
# 1                                            Ericsson  0.223562      0.348837
# 2                                            Qualcomm  0.218622      0.350981
# 3                                       Cisco Systems  0.382149      0.618974
# 4                                               Afero  0.373407      0.630410
# 5                                                 IBM  0.390548      0.647998
# 6                                           Microsoft  0.418443      0.586912
# 7                                Convida Wireless LLC  0.520110      0.658039
# 8                                               Apple  0.520518      0.646072
# 9                                               Nokia  0.602767      0.754441
# 10                                              Nokia  0.776176      0.938649
# 11                             Verizon Communications  0.645419      0.931700
# 12  Electronics and Telecommunications Research In...  0.672368      0.928629
# 13                                     LG Electronics  0.657098      0.902106
# 14                                               Sony       NaN           NaN
# 15                                                NEC       NaN           NaN
# 16                                         NTT Docomo       NaN           NaN
# 17                                Amazon Technologies       NaN           NaN
# 18                                              Sharp       NaN           NaN
# 19                                               AT&T       NaN           NaN
# 20                                  Micron Technology       NaN           NaN
# 21                                Huawei Technologies       NaN           NaN
# 22                                       T_Mobile_USA       NaN           NaN
# 23                                    Shanghai_Langbo       NaN           NaN
# 24                                                EMC       NaN           NaN
#
#     cpc_2016  country_2016  cpc_2017  country_2017  cpc_2018  country_2018  \
# 0   0.167661      0.355784  0.071131      0.278684  0.072211      0.268343
# 1   0.308044      0.414100  0.048276      0.199208  0.058596      0.200094
# 2   0.242999      0.338823  0.042257      0.181205  0.068832      0.175903
# 3   0.487658      0.747794  0.200960      0.472250  0.152728      0.421779
# 4        NaN           NaN       NaN           NaN       NaN           NaN
# 5   0.473348      0.750641  0.101298      0.337349  0.078946      0.354751
# 6   0.679417      0.839824  0.256167      0.470661  0.198228      0.412801
# 7   0.966294      1.111789       NaN           NaN       NaN           NaN
# 8        NaN           NaN  0.447966      0.695625  0.250076      0.431241
# 9   1.041511      1.183638  0.393310      0.557917  0.255761      0.412338
# 10  1.041511      1.183638  0.393310      0.557917  0.255761      0.412338
# 11       NaN           NaN       NaN           NaN  0.410591      0.724856
# 12  0.916571      1.164640       NaN           NaN       NaN           NaN
# 13  0.446896      0.677922  0.239578      0.485734  0.292912      0.478541
# 14  0.867005      0.981388  0.460100      0.613852  0.319085      0.456556
# 15  0.877540      0.976184  0.397937      0.524854  0.422004      0.553665
# 16  0.954544      1.051920  0.273098      0.398911       NaN           NaN
# 17  1.013720      1.298348  0.414712      0.663373  0.415172      0.711983
# 18       NaN           NaN  0.442306      0.554382       NaN           NaN
# 19       NaN           NaN       NaN           NaN  0.423999      0.727927
# 20       NaN           NaN       NaN           NaN       NaN           NaN
# 21       NaN           NaN       NaN           NaN       NaN           NaN
# 22       NaN           NaN       NaN           NaN       NaN           NaN
# 23       NaN           NaN       NaN           NaN       NaN           NaN
# 24       NaN           NaN       NaN           NaN       NaN           NaN
#
#     cpc_2019  country_2019  cpc_2020  country_2020
# 0   0.125446      0.304417  0.076885      0.328528
# 1   0.097531      0.198698       NaN           NaN
# 2   0.134405      0.222809  0.154709      0.356850
# 3   0.132213      0.373297  0.250489      0.553770
# 4        NaN           NaN       NaN           NaN
# 5   0.046212      0.313657  0.150950      0.477923
# 6   0.168210      0.378882  0.330829      0.646414
# 7        NaN           NaN       NaN           NaN
# 8   0.233415      0.413501       NaN           NaN
# 9   0.442163      0.585204  0.579833      0.752980
# 10  0.442163      0.585204  0.579833      0.752980
# 11  0.314515      0.581273  0.285505      0.623467
# 12       NaN           NaN       NaN           NaN
# 13  0.091827      0.266057  0.110144      0.338225
# 14  0.323146      0.432788       NaN           NaN
# 15       NaN           NaN       NaN           NaN
# 16       NaN           NaN       NaN           NaN
# 17       NaN           NaN       NaN           NaN
# 18       NaN           NaN       NaN           NaN
# 19  0.208707      0.459859  0.250316      0.565751
# 20  0.209216      0.433792  0.242545      0.475925
# 21  0.265645      0.385131  0.183824      0.339929
# 22       NaN           NaN  0.494456      0.786497
# 23       NaN           NaN  0.585771      0.800440
# 24       NaN           NaN  0.591743      0.903454

# %%
cpc_ls = list(-us_all[us_all.company=="LG Electronics"].iloc[:,[1,3,5,7,9,11]].values[0])
country_ls = list(-us_all[us_all.company=="LG Electronics"].iloc[:,[2,4,6,8,10,12]].values[0])
year = list(range(2015,2021))

# %%
-us_all[us_all.company=="Intel"].iloc[:,[1,3,5,7,9,11]].values[0]
# Out:
# array([-0.06004114, -0.16766145, -0.07113094, -0.07221143, -0.12544598,
#        -0.07688506])

# %%
df = pd.DataFrame((zip(year, cpc_ls, country_ls)), columns = ['year','cpc', 'country'])

# %%
df
# Out:
#    year       cpc   country
# 0  2015 -0.657098 -0.902106
# 1  2016 -0.446896 -0.677922
# 2  2017 -0.239578 -0.485734
# 3  2018 -0.292912 -0.478541
# 4  2019 -0.091827 -0.266057
# 5  2020 -0.110144 -0.338225

# %% [markdown]
# # Scatter plot

# %%
plt.figure(figsize=(6,6))
plt.style.use('ggplot')

plt.plot("cpc", "country", data=df, linestyle='-', marker='o')
# plt.scatter(-c_df.cpc, -c_df.country, alpha=0.5)

plt.title("USPTO \n - LG Electronics")
plt.xlabel("LDA similarity")
plt.ylabel("Patent Family")


for i, txt in enumerate(df.year):
    plt.text(df.cpc[i]+0.0015, df.country[i],txt)


plt.show()
