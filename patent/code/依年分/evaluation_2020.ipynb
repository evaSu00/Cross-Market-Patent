# %%
import numpy as np
import pandas as pd
import os

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from scipy.special import rel_entr
from scipy.stats import entropy
import scipy.stats
import math
import warnings 
warnings.filterwarnings("ignore") 

from sklearn.metrics.cluster import normalized_mutual_info_score, adjusted_rand_score

# %%
# 使用GPU
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
! nvidia-smi
# Out:
# Thu Jun  9 00:36:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.103.01   Driver Version: 470.103.01   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 44%   48C    P8    22W / 260W |     22MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 30%   38C    P8    24W / 260W |      8MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1798      G   /usr/lib/xorg/Xorg                  9MiB |
# |    0   N/A  N/A      2153      G   /usr/bin/gnome-shell                7MiB |
# |    1   N/A  N/A      1798      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # MongoDB

# %%
from pymongo import MongoClient
import pymongo

# %%
mongoURI = "mongodb://%s:%s@%s/%s?authMechanism=SCRAM-SHA-1" % ("eva", "eva_30241", "140.117.69.70:30241", "eva")

try:
    conn = pymongo.MongoClient(mongoURI)
    db = conn.eva
    # db_de = db.patent_de
    # db_us = db.patent_us
    # db_cn = db.patent_cn

    db_rm_cn_2020 = db.rm_patent_cn_2020
    db_rm_us_2020 = db.rm_patent_us_2020
    db_rm_de_2020 = db.rm_patent_de_2020

    
except errors.ConnectionFailure as err:
    print(err)

# %% [markdown]
# # 2020

# %% [markdown]
# ## Company數量

# %%
data_assignee = db_rm_de_2020.aggregate([
    {"$unwind" : "$current_assignee"},
    {"$group" : {"_id" : "$current_assignee", "count":{"$sum":1}}},
    {"$sort": {"count":-1}}
    # {"$limit":30}
])

ls_company = []
ls_count = []
for data in data_assignee:
    # print(data["_id"],data["count"])
    ls_company.append(data["_id"])
    ls_count.append(data["count"])

# %%
df_family_de = pd.DataFrame((zip(ls_company, ls_count)), columns = ['company', 'count'])

# %%
data_assignee = db_rm_cn_2020.aggregate([
    {"$unwind" : "$current_assignee"},
    {"$group" : {"_id" : "$current_assignee", "count":{"$sum":1}}},
    {"$sort": {"count":-1}}
    # {"$limit":30}
])

ls_company = []
ls_count = []
for data in data_assignee:
    # print(data["_id"],data["count"])
    ls_company.append(data["_id"])
    ls_count.append(data["count"])
    
df_family_cn = pd.DataFrame((zip(ls_company, ls_count)), columns = ['company', 'count'])

# %%
data_assignee = db_rm_us_2020.aggregate([
    {"$unwind" : "$current_assignee"},
    {"$group" : {"_id" : "$current_assignee", "count":{"$sum":1}}},
    {"$sort": {"count":-1}}
    # {"$limit":30}
])

ls_company = []
ls_count = []
for data in data_assignee:
    # print(data["_id"],data["count"])
    ls_company.append(data["_id"])
    ls_count.append(data["count"])
    
df_family_us = pd.DataFrame((zip(ls_company, ls_count)), columns = ['company', 'count'])

# %%
final_df = pd.concat([df_family_de,df_family_cn,df_family_us],axis=0)

# %%
# 取總數前30家公司
final_df.groupby("company").sum().reset_index().sort_values("count",ascending=False).head(30)
# Out:
#                                                 company  count
# 2977                                       Qualcomm Inc   1907
# 3131                         Samsung Electronics Co Ltd    796
# 1964                                         Intel Corp    558
# 1793                         Huawei Technologies Co Ltd    530
# 2250                                 LG Electronics Inc    354
# 1973               International Business Machines Corp    238
# 185                                           Apple Inc    195
# 3351    Shanghai Langbo Communication Technology Co Ltd    182
# 2414                              Micron Technology Inc    167
# 22                      AT&T Intellectual Property I LP    147
# 835                                Cisco Technology Inc    144
# 4317                   Verizon Patent and Licensing Inc    128
# 2415                 Microsoft Technology Licensing LLC    114
# 4117                 Telefonaktiebolaget LM Ericsson AB     91
# 761    China United Network Communications Group Co Ltd     70
# 4066                                   T Mobile USA Inc     70
# 2717                              Nokia Technologies Oy     66
# 1338  Guangdong Oppo Mobile Telecommunications Corp Ltd     62
# 729            China Mobile Communications Group Co Ltd     62
# 88                            Alibaba Group Holding Ltd     61
# 3937                      State Grid Corp of China SGCC     60
# 444               Beijing Xiaomi Mobile Software Co Ltd     59
# 1027                                           EMC Corp     56
# 2386                                       MediaTek Inc     51
# 404            Beijing Sankuai Online Technology Co Ltd     51
# 4127                 Tencent Technology Shenzhen Co Ltd     50
# 2387                         MediaTek Singapore Pte Ltd     47
# 1065  Electronics and Telecommunications Research In...     46
# 2757                                         Ofinno LLC     46
# 737                             China Mobile IoT Co Ltd     44

# %%
com_df = final_df.groupby("company").sum().reset_index().sort_values("count",ascending=False).head(30)
com_df.reset_index(drop=True, inplace=True)

# %%
com_df["count_log"] = com_df["count"].apply(lambda x: np.log(x))
com_df
# Out:
#                                               company  count  count_log
# 0                                        Qualcomm Inc   1907   7.553287
# 1                          Samsung Electronics Co Ltd    796   6.679599
# 2                                          Intel Corp    558   6.324359
# 3                          Huawei Technologies Co Ltd    530   6.272877
# 4                                  LG Electronics Inc    354   5.869297
# 5                International Business Machines Corp    238   5.472271
# 6                                           Apple Inc    195   5.273000
# 7     Shanghai Langbo Communication Technology Co Ltd    182   5.204007
# 8                               Micron Technology Inc    167   5.117994
# 9                     AT&T Intellectual Property I LP    147   4.990433
# 10                               Cisco Technology Inc    144   4.969813
# 11                   Verizon Patent and Licensing Inc    128   4.852030
# 12                 Microsoft Technology Licensing LLC    114   4.736198
# 13                 Telefonaktiebolaget LM Ericsson AB     91   4.510860
# 14   China United Network Communications Group Co Ltd     70   4.248495
# 15                                   T Mobile USA Inc     70   4.248495
# 16                              Nokia Technologies Oy     66   4.189655
# 17  Guangdong Oppo Mobile Telecommunications Corp Ltd     62   4.127134
# 18           China Mobile Communications Group Co Ltd     62   4.127134
# 19                          Alibaba Group Holding Ltd     61   4.110874
# 20                      State Grid Corp of China SGCC     60   4.094345
# 21              Beijing Xiaomi Mobile Software Co Ltd     59   4.077537
# 22                                           EMC Corp     56   4.025352
# 23                                       MediaTek Inc     51   3.931826
# 24           Beijing Sankuai Online Technology Co Ltd     51   3.931826
# 25                 Tencent Technology Shenzhen Co Ltd     50   3.912023
# 26                         MediaTek Singapore Pte Ltd     47   3.850148
# 27  Electronics and Telecommunications Research In...     46   3.828641
# 28                                         Ofinno LLC     46   3.828641
# 29                            China Mobile IoT Co Ltd     44   3.784190

# %% [markdown]
# 公司名稱正規化

# %%
com_df["company"] = com_df.company.apply(lambda x: x.replace(" Inc","")\
                                                    .replace(" Co Ltd","")\
                                                    .replace(" Corp","")\
                                                    .replace("International Business Machines","IBM"))

# %%
com_df
# Out:
#                                               company  count  count_log
# 0                                            Qualcomm   1907   7.553287
# 1                                 Samsung Electronics    796   6.679599
# 2                                               Intel    558   6.324359
# 3                                 Huawei Technologies    530   6.272877
# 4                                      LG Electronics    354   5.869297
# 5                                                 IBM    238   5.472271
# 6                                               Apple    195   5.273000
# 7            Shanghai Langbo Communication Technology    182   5.204007
# 8                                   Micron Technology    167   5.117994
# 9                     AT&T Intellectual Property I LP    147   4.990433
# 10                                   Cisco Technology    144   4.969813
# 11                       Verizon Patent and Licensing    128   4.852030
# 12                 Microsoft Technology Licensing LLC    114   4.736198
# 13                 Telefonaktiebolaget LM Ericsson AB     91   4.510860
# 14          China United Network Communications Group     70   4.248495
# 15                                       T Mobile USA     70   4.248495
# 16                              Nokia Technologies Oy     66   4.189655
# 17       Guangdong Oppo Mobile Telecommunications Ltd     62   4.127134
# 18                  China Mobile Communications Group     62   4.127134
# 19                          Alibaba Group Holding Ltd     61   4.110874
# 20                           State Grid of China SGCC     60   4.094345
# 21                     Beijing Xiaomi Mobile Software     59   4.077537
# 22                                                EMC     56   4.025352
# 23                                           MediaTek     51   3.931826
# 24                  Beijing Sankuai Online Technology     51   3.931826
# 25                        Tencent Technology Shenzhen     50   3.912023
# 26                         MediaTek Singapore Pte Ltd     47   3.850148
# 27  Electronics and Telecommunications Research In...     46   3.828641
# 28                                         Ofinno LLC     46   3.828641
# 29                                   China Mobile IoT     44   3.784190

# %%
com_ls = list(com_df.company)

# %% [markdown]
# # Data 2020

# %% [markdown]
# 富比士2000資料

# %%
f_data = pd.read_csv("./Forbes/Forbes_2020.csv")

# %%
f_data[f_data["Industry"]=="Semiconductors"]
# Out:
#       Rank                        Company Country/Territory     Sales  \
# 15      16            Samsung Electronics       South Korea  $197.6 B
# 37      38                          Intel     United States   $75.7 B
# 107    108           Taiwan Semiconductor            Taiwan   $37.8 B
# 191    192                       Broadcom     United States   $22.7 B
# 257    258                       Qualcomm     United States   $24.7 B
# 276    277              Micron Technology     United States   $19.6 B
# 295    296                       SK Hynix       South Korea   $23.2 B
# 360    361                   ASML Holding       Netherlands   $13.4 B
# 415    416              Texas Instruments     United States   $14.1 B
# 435    436              Applied Materials     United States     $15 B
# 488    489                         NVIDIA     United States   $10.9 B
# 658    659                   Lam Research     United States    $9.6 B
# 693    693                 Tokyo Electron             Japan   $10.4 B
# 719    720                 Analog Devices     United States    $5.8 B
# 762    763          Infineon Technologies           Germany    $8.9 B
# 821    822             STMicroelectronics       Switzerland    $9.7 B
# 869    870                       MediaTek            Taiwan      $8 B
# 875    876         ASE Technology Holding            Taiwan   $13.7 B
# 1024  1025             NXP Semiconductors       Netherlands    $8.8 B
# 1038  1039         Advanced Micro Devices     United States    $7.2 B
# 1039  1040           Microchip Technology     United States    $5.3 B
# 1087  1088       Marvell Technology Group           Bermuda    $2.7 B
# 1179  1180  Longi Green Energy Technology             China    $5.1 B
# 1202  1203                         Xilinx     United States    $3.2 B
# 1234  1235             Skyworks Solutions     United States    $3.3 B
# 1297  1298      Maxim Integrated Products     United States    $2.2 B
# 1659  1660            Renesas Electronics             Japan    $6.9 B
#
#        Profits    Assets Market Value                  Sector        Industry
# 15     $18.4 B  $304.9 B     $278.7 B  Information Technology  Semiconductors
# 37     $22.7 B  $147.7 B       $254 B  Information Technology  Semiconductors
# 107      $13 B   $77.5 B     $265.5 B  Information Technology  Semiconductors
# 191     $2.6 B     $81 B     $108.6 B  Information Technology  Semiconductors
# 257       $4 B   $31.9 B      $88.5 B  Information Technology  Semiconductors
# 276     $2.3 B   $49.6 B      $53.3 B  Information Technology  Semiconductors
# 295     $1.3 B   $55.2 B        $47 B  Information Technology  Semiconductors
# 360     $2.9 B   $25.5 B     $124.5 B  Information Technology  Semiconductors
# 415     $4.9 B   $17.3 B     $106.5 B  Information Technology  Semiconductors
# 435     $2.8 B   $19.8 B      $45.6 B  Information Technology  Semiconductors
# 488     $2.8 B   $17.3 B       $179 B  Information Technology  Semiconductors
# 658     $2.1 B   $12.9 B      $37.1 B  Information Technology  Semiconductors
# 693     $1.7 B   $11.8 B      $33.4 B  Information Technology  Semiconductors
# 719     $1.2 B   $21.4 B      $40.4 B  Information Technology  Semiconductors
# 762   $924.5 M   $16.4 B      $23.1 B  Information Technology  Semiconductors
# 821       $1 B   $11.9 B      $23.1 B  Information Technology  Semiconductors
# 869   $745.1 M   $15.3 B      $22.1 B  Information Technology  Semiconductors
# 875   $619.2 M   $18.9 B       $9.6 B  Information Technology  Semiconductors
# 1024    $243 M   $19.5 B      $27.8 B  Information Technology  Semiconductors
# 1038    $487 M    $5.9 B      $61.4 B  Information Technology  Semiconductors
# 1039  $645.4 M   $17.6 B        $21 B  Information Technology  Semiconductors
# 1087    $1.6 B   $11.1 B      $17.7 B  Information Technology  Semiconductors
# 1179  $937.6 M    $8.9 B      $16.5 B  Information Technology  Semiconductors
# 1202  $792.7 M    $4.7 B      $21.7 B  Information Technology  Semiconductors
# 1234  $825.8 M    $5.1 B      $17.6 B  Information Technology  Semiconductors
# 1297    $815 M    $3.5 B      $14.8 B  Information Technology  Semiconductors
# 1659  $141.4 M   $15.4 B       $9.3 B  Information Technology  Semiconductors

# %%
Ind_ls = list(f_data[f_data["Industry"]=="Semiconductors"].Company)

# %% [markdown]
# ## 使用company top 30 做join

# %%
forb_ls = list(np.where(com_df.company.isin(Ind_ls), 1, 0))

# %%
# pbc 0.09,0.09
comp_ls = ["Huawei Technologies","Intel","LG Electronics","Qualcomm","Apple","Shanghai Langbo Communication Technology","IBM","Micron Technology"]

# %%
competitor_ls = list(np.where(com_df.company.isin(comp_ls), 1, 0))

# %%
# (labels_true, labels_pred)
nmi = normalized_mutual_info_score(forb_ls,competitor_ls)
ari = adjusted_rand_score(forb_ls,competitor_ls)

print("nmi: ",nmi)
print("ari: ", ari)
# Out:
# nmi:  0.0984875376196977
# ari:  0.19439811353309944

# %% [markdown]
# ## 使用Forbes做join

# %%
forb_ls = list(np.where(f_data.Company.isin(Ind_ls), 1, 0))

# %%
# pbc 0.09,0.09
comp_ls = ["Huawei Technologies","Intel","LG Electronics","Qualcomm","Apple","Shanghai Langbo Communication Technology","IBM","Micron Technology"]

# %%
competitor_ls = list(np.where(f_data.Company.isin(comp_ls), 1, 0))

# %%
# (labels_true, labels_pred)
nmi = normalized_mutual_info_score(forb_ls,competitor_ls)
ari = adjusted_rand_score(forb_ls,competitor_ls)

print("nmi: ",nmi)
print("ari: ", ari)
# Out:
# nmi:  0.09748332626658215
# ari:  0.1753376488020819
