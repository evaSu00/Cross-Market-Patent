# %%
import numpy as np
import pandas as pd
import os

# %%
! nvidia-smi
# Out:
# Wed Jun 29 00:50:42 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.129.06   Driver Version: 470.129.06   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 32%   41C    P8    21W / 260W |     22MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# 使用GPU
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# # Data

# %%
cpc_2020 = pd.read_csv("../competitor_df/cpc_us_2020.csv")
cpc_2019 = pd.read_csv("../competitor_df/cpc_us_2019.csv")
cpc_2018 = pd.read_csv("../competitor_df/cpc_us_2018.csv")

# %%
cpc_2020
# Out:
#                                      company  2020_competitor  2020_forb
# 0                                   Qualcomm                1          1
# 1                                      Intel                1          1
# 2                             LG Electronics                1          3
# 3                                        IBM                1          2
# 4                        Huawei Technologies                1          4
# 5                          Micron Technology                1          1
# 6                                       AT&T                1          3
# 7                              Cisco Systems                1          2
# 8                     Verizon Communications                3          3
# 9                                  Microsoft                1          2
# 10                              T Mobile USA                4          4
# 11  Shanghai Langbo Communication Technology                4          4
# ...

# %%
cpc_2019
# Out:
#                    company  2019_competitor  2019_forb
# 0                 Qualcomm                1          1
# 1           LG Electronics                1          3
# 2                      IBM                1          2
# 3                 Ericsson                2          2
# 4                    Intel                1          1
# 5            Cisco Systems                2          2
# 6                Microsoft                1          2
# 7                    Apple                4          2
# 8                     AT&T                4          3
# 9        Micron Technology                3          1
# 10     Huawei Technologies                2          4
# 11                    Sony                4          3
# 12  Verizon Communications                4          3
# 13                   Nokia                4          2

# %%
cpc_2019.iloc[:,0:2]
# Out:
#                    company  2019_competitor
# 0                 Qualcomm                1
# 1           LG Electronics                1
# 2                      IBM                1
# 3                 Ericsson                2
# 4                    Intel                1
# 5            Cisco Systems                2
# 6                Microsoft                1
# 7                    Apple                4
# 8                     AT&T                4
# 9        Micron Technology                3
# 10     Huawei Technologies                2
# 11                    Sony                4
# 12  Verizon Communications                4
# 13                   Nokia                4

# %%
cpc_all = cpc_2018.iloc[:,0:2].merge(cpc_2019.iloc[:,0:2],on = 'company',how = 'outer')
# cpc_all = cpc_all.merge(cpc_2020.iloc[:,0:2],on = 'company',how = 'outer')

# %%
cpc_all
# Out:
#                    company  2018_competitor  2019_competitor
# 0                 Qualcomm              1.0              1.0
# 1                 Ericsson              1.0              2.0
# 2                    Intel              1.0              1.0
# 3                      IBM              1.0              1.0
# 4            Cisco Systems              1.0              2.0
# 5                Microsoft              1.0              1.0
# 6                    Apple              2.0              4.0
# 7                    Nokia              2.0              4.0
# 8           LG Electronics              4.0              1.0
# 9                     Sony              4.0              4.0
# 10  Verizon Communications              4.0              4.0
# 11                     NEC              4.0              NaN
# 12     Amazon Technologies              4.0              NaN
# 13                    AT&T              4.0              4.0
# ...

# %%
com_ls = list(cpc_all.company)

# %% [markdown]
# ## Forbes list
# - 同Industry：1
# - 同Sector：2
# - 有出現在company list：3
# - Company list上有但Forbes沒有：4

# %%
f_data = pd.read_csv("../../Forbes/Forbes_2015.csv")

# %%
forb_ls =[]

for i in com_ls:
    if (f_data["Company"]==i).any():
        if (f_data[f_data.Company==i]["Industry"]=="Semiconductors").any():
            forb_ls.append(1)
        elif (f_data[f_data.Company==i]["Sector"]=="Information Technology").any():
            forb_ls.append(2)
        else:
            forb_ls.append(3)
    else:
        forb_ls.append(4)

# %%
forb_ls
# Out:
# [1, 2, 1, 2, 2, 2, 2, 2, 3, 3, 3, 2, 4, 3, 1, 4]

# %%
cpc_all["forb_2015"] = forb_ls

# %%
cpc_all
# Out:
#                    company  2018_competitor  2019_competitor  forb_2019  \
# 0                 Qualcomm              1.0              1.0          1
# 1                 Ericsson              1.0              2.0          2
# 2                    Intel              1.0              1.0          1
# 3                      IBM              1.0              1.0          2
# 4            Cisco Systems              1.0              2.0          2
# 5                Microsoft              1.0              1.0          2
# 6                    Apple              2.0              4.0          2
# 7                    Nokia              2.0              4.0          2
# 8           LG Electronics              4.0              1.0          3
# 9                     Sony              4.0              4.0          3
# 10  Verizon Communications              4.0              4.0          3
# 11                     NEC              4.0              NaN          2
# ...

# %%
len(cpc_all[cpc_all["2020_competitor"]==cpc_all["forb_2020"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/anaconda3/envs/test/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /usr/local/anaconda3/envs/test/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/anaconda3/envs/test/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020_competitor'
#
# ...

# %%
# 當年正確預測比例
len(cpc_all[cpc_all["2020_competitor"]==cpc_all["forb_2020"]])/len(cpc_all)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/anaconda3/envs/test/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /usr/local/anaconda3/envs/test/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/anaconda3/envs/test/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020_competitor'
#
# ...

# %%
# 轉換比例
cpc_all[(cpc_all["2020_competitor"]==cpc_all["forb_2020"])&(cpc_all["2019_competitor"]!=1)]
# Out:
#                                      company  2018_competitor  \
# 10                    Verizon Communications              4.0
# 14                         Micron Technology              NaN
# 16                              T Mobile USA              NaN
# 17  Shanghai Langbo Communication Technology              NaN
# 18                                       EMC              NaN
#
#     2019_competitor  2020_competitor  forb_2019  forb_2020
# 10              4.0              3.0          3          3
# 14              3.0              1.0          1          1
# 16              NaN              4.0          4          4
# 17              NaN              4.0          4          4
# 18              NaN              4.0          4          4

# %%
len(cpc_all[(cpc_all["2020_competitor"]==cpc_all["forb_2020"])&(cpc_all["2019_competitor"]!=1)])/len(cpc_all)
# Out:
# 0.2631578947368421
