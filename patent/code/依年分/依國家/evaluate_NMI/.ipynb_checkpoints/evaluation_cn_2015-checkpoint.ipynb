# %%
import numpy as np
import pandas as pd
import os

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from scipy.special import rel_entr
from scipy.stats import entropy
import scipy.stats
import math
import warnings 
warnings.filterwarnings("ignore") 

from sklearn.metrics.cluster import normalized_mutual_info_score, adjusted_rand_score

# %%
# 使用GPU
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
! nvidia-smi
# Out:
# Wed Jun 29 01:33:57 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.129.06   Driver Version: 470.129.06   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 32%   41C    P8    21W / 260W |     22MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 30%   38C    P8    24W / 260W |      8MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      6976      G   /usr/lib/xorg/Xorg                  9MiB |
# |    0   N/A  N/A      7277      G   /usr/bin/gnome-shell                7MiB |
# |    1   N/A  N/A      6976      G   /usr/lib/xorg/Xorg                  4MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # MongoDB

# %%
from pymongo import MongoClient
import pymongo

# %%
mongoURI = "mongodb://%s:%s@%s/%s?authMechanism=SCRAM-SHA-1" % ("eva", "eva_30241", "140.117.69.70:30241", "eva")

try:
    conn = pymongo.MongoClient(mongoURI)
    db = conn.eva
    # db_de = db.patent_de
    # db_us = db.patent_us
    # db_cn = db.patent_cn

    db_rm_cn_2015 = db.rm_patent_cn_2015
    db_rm_us_2015 = db.rm_patent_us_2015
    db_rm_de_2015 = db.rm_patent_de_2015

    
except errors.ConnectionFailure as err:
    print(err)

# %% [markdown]
# # 2015

# %% [markdown]
# ## Company數量

# %%
data_assignee = db_rm_de_2015.aggregate([
    {"$unwind" : "$current_assignee"},
    {"$group" : {"_id" : "$current_assignee", "count":{"$sum":1}}},
    {"$sort": {"count":-1}},
    {"$limit":30}
])

ls_company = []
ls_count = []
for data in data_assignee:
    # print(data["_id"],data["count"])
    ls_company.append(data["_id"])
    ls_count.append(data["count"])

# %%
df_family_de = pd.DataFrame((zip(ls_company, ls_count)), columns = ['company', 'count'])

# %%
data_assignee = db_rm_cn_2015.aggregate([
    {"$unwind" : "$current_assignee"},
    {"$group" : {"_id" : "$current_assignee", "count":{"$sum":1}}},
    {"$sort": {"count":-1}},
    {"$limit":30}
])

ls_company = []
ls_count = []
for data in data_assignee:
    # print(data["_id"],data["count"])
    ls_company.append(data["_id"])
    ls_count.append(data["count"])
    
df_family_cn = pd.DataFrame((zip(ls_company, ls_count)), columns = ['company', 'count'])

# %%
data_assignee = db_rm_us_2015.aggregate([
    {"$unwind" : "$current_assignee"},
    {"$group" : {"_id" : "$current_assignee", "count":{"$sum":1}}},
    {"$sort": {"count":-1}},
    {"$limit":30}
])

ls_company = []
ls_count = []
for data in data_assignee:
    # print(data["_id"],data["count"])
    ls_company.append(data["_id"])
    ls_count.append(data["count"])
    
df_family_us = pd.DataFrame((zip(ls_company, ls_count)), columns = ['company', 'count'])

# %%
# final_df = pd.concat([df_family_de,df_family_cn,df_family_us],axis=0)

# %%
# 取總數前15家公司
df_family_cn.groupby("company").sum().reset_index().sort_values("count",ascending=False).head(15)
# Out:
#                                               company  count
# 0              Chengdu Qinchuan IoT Technology Co Ltd     82
# 19                SUZHOU XUANHE IOT TECHNOLOGY Co Ltd     81
# 10        Jiangsu IoT Research and Development Center     61
# 13             Nanjing Hansense Iot Technology Co Ltd     26
# 14               Nanjing IoT Sensor Technology Co Ltd     25
# 4    GUANGDONG ABEJ IOT INTELLIGENT TECHNOLOGY Co Ltd     24
# 7                          Huawei Technologies Co Ltd     19
# 20                         Samsung Electronics Co Ltd     17
# 17  SHENZHEN QIANHAI LINGJU INTERNET OF THINGS SCI...     16
# 22      Shenzhen Qianhai Livall IoT Technology Co Ltd     16
# 24   Tianjin Hui Zhiwulian Science And Technology Ltd     15
# 12                                    Mangoiot Co Ltd     14
# 1                          Chongqing Liuhe Iot Co Ltd     14
# 8                 Huizhou Sanhe Iot Technology Co Ltd     13
# 26           Xian Irain IoT Technology Service Co Ltd     12

# %%
com_df = df_family_cn.groupby("company").sum().reset_index().sort_values("count",ascending=False).head(15)
com_df.reset_index(drop=True, inplace=True)

# %%
com_df["count_log"] = com_df["count"].apply(lambda x: np.log(x))
com_df
# Out:
#                                               company  count  count_log
# 0              Chengdu Qinchuan IoT Technology Co Ltd     82   4.406719
# 1                 SUZHOU XUANHE IOT TECHNOLOGY Co Ltd     81   4.394449
# 2         Jiangsu IoT Research and Development Center     61   4.110874
# 3              Nanjing Hansense Iot Technology Co Ltd     26   3.258097
# 4                Nanjing IoT Sensor Technology Co Ltd     25   3.218876
# 5    GUANGDONG ABEJ IOT INTELLIGENT TECHNOLOGY Co Ltd     24   3.178054
# 6                          Huawei Technologies Co Ltd     19   2.944439
# 7                          Samsung Electronics Co Ltd     17   2.833213
# 8   SHENZHEN QIANHAI LINGJU INTERNET OF THINGS SCI...     16   2.772589
# 9       Shenzhen Qianhai Livall IoT Technology Co Ltd     16   2.772589
# 10   Tianjin Hui Zhiwulian Science And Technology Ltd     15   2.708050
# 11                                    Mangoiot Co Ltd     14   2.639057
# 12                         Chongqing Liuhe Iot Co Ltd     14   2.639057
# 13                Huizhou Sanhe Iot Technology Co Ltd     13   2.564949
# 14           Xian Irain IoT Technology Service Co Ltd     12   2.484907

# %% [markdown]
# 公司名稱正規化

# %%
com_df["company"] = com_df.company.apply(lambda x: x.replace(" Inc","")\
                                                    .replace(" Co Ltd","")\
                                                    .replace(" Co. Ltd.","")\
                                                    .replace(" Co., Ltd.","")\
                                                    .replace(" Ltd","")\
                                                    .replace(" Corp","")\
                                                    .replace("..","")\
                                                    .replace("International Business Machines","IBM")\
                                                    .replace("Nippon Telegraph and Telephone","Nippon Telegraph & Tel")\
                                                    .replace("Alibaba Group Holding Ltd","Alibaba")\
                                                    .replace("ZTE Intelligent IoT Technology","ZTE")\
                                                    .replace("AT&T Intellectual Property I LP","AT&T")\
                                                    .replace("Microsoft Technology Licensing LLC","Microsoft")\
                                                    .replace("Telefonaktiebolaget LM Ericsson AB","Ericsson")\
                                                    .replace("Cisco Technology","Cisco Systems")\
                                                    .replace("Verizon Patent and Licensing","Verizon Communications")\
                                                    .replace("Tencent Technology Shenzhen","Tencent Holdings")\
                                                    .replace("China Mobile Communications Group","China Mobile")\
                                                    .replace("Alipay Hangzhou Information Technology","Alibaba Group")\
                                                    .replace("Beijing Xiaomi Mobile Software","Xiaomi"))

# %%
com_df
# Out:
#                                               company  count  count_log
# 0                     Chengdu Qinchuan IoT Technology     82   4.406719
# 1                        SUZHOU XUANHE IOT TECHNOLOGY     81   4.394449
# 2         Jiangsu IoT Research and Development Center     61   4.110874
# 3                     Nanjing Hansense Iot Technology     26   3.258097
# 4                       Nanjing IoT Sensor Technology     25   3.218876
# 5           GUANGDONG ABEJ IOT INTELLIGENT TECHNOLOGY     24   3.178054
# 6                                 Huawei Technologies     19   2.944439
# 7                                 Samsung Electronics     17   2.833213
# 8   SHENZHEN QIANHAI LINGJU INTERNET OF THINGS SCI...     16   2.772589
# 9              Shenzhen Qianhai Livall IoT Technology     16   2.772589
# 10       Tianjin Hui Zhiwulian Science And Technology     15   2.708050
# 11                                           Mangoiot     14   2.639057
# 12                                Chongqing Liuhe Iot     14   2.639057
# 13                       Huizhou Sanhe Iot Technology     13   2.564949
# 14                  Xian Irain IoT Technology Service     12   2.484907

# %%
com_ls = list(com_df.company)

# %%
com_ls.remove('Samsung Electronics')

# %% [markdown]
# # Data 2015

# %% [markdown]
# 富比士2000資料

# %%
f_data = pd.read_csv("../../Forbes/Forbes_2015.csv")

# %%
f_data[f_data["Industry"]=="Semiconductors"]
# Out:
#                       Company  Market Value  Revenue  Profits   Assets  Rank  \
# 17        Samsung Electronics       199.356  195.891  21.9278  209.637    18
# 66                      Intel       147.197   55.870  11.7040   91.956    67
# 155                  Qualcomm       111.774   26.964   8.0630   48.447   156
# 157      Taiwan Semiconductor       123.323   25.173   8.7086   47.311   158
# 353                  SK Hynix        29.994   16.269   3.9856   24.458   354
# 354         Micron Technology        29.551   16.948   3.8930   23.818   355
# 417         Texas Instruments        59.488   13.045   2.7780   17.722   418
# 592              ASML Holding        44.830    7.768   1.5897   15.812   593
# 681         Applied Materials        27.228    9.241   1.1670   13.073   682
# 787                  Mediatek        20.947    7.031   1.5311   11.111   788
# 825                  Broadcom        25.817    8.428   0.6520   12.215   826
# 999    Advanced Semiconductor        10.859    8.467   0.7786   10.568  1000
# 1060       Avago Technologies        32.285    5.195   0.4800   10.697  1061
# 1124    Infineon Technologies        13.879    5.921   0.7746    7.495  1125
# 1130       NXP Semiconductors        23.249    5.647   0.5390    6.893  1131
# 1171      Renesas Electronics        12.551    7.646   0.5466    7.128  1172
# 1278           Analog Devices        19.564    3.009   0.6555    6.821  1279
# 1294           Tokyo Electron        12.436    6.146   0.5071    6.936  1294
# 1328             Lam Research        11.527    4.852   0.7158    8.111  1329
# 1347         Inotera Memories         8.580    2.725   1.7461    4.361  1348
# 1356  Skyworks Solutions Inc.        18.218    2.592   0.5584    3.191  1357
# 1378                   NVIDIA        11.912    4.682   0.6306    7.201  1379
# 1409             ARM Holdings        23.181    1.309   0.4205    2.877  1410
# 1471                   Xilinx        10.978    2.428   0.6696    4.915  1472
# 1565                   Altera        12.404    1.932   0.4727    5.674  1566
# 1596        Linear Technology        11.060    1.437   0.5004    1.729  1597
# 1761         Nanya Technology         6.009    1.621   0.9300    3.308  1762
# 1769       STMicroelectronics         8.624    7.400   0.1290    9.008  1768
# 1826               KLA-Tencor         9.457    2.881   0.4248    4.987  1826
# 1909     Microchip Technology         9.734    2.097   0.3811    4.629  1909
# 1951  Freescale Semiconductor        12.439    4.634   0.2510    3.275  1951
# 1967                     Rohm         7.833    3.345   0.4550    7.155  1968
#
#                       Sector        Industry      Continent         Country  \
# 17    Information Technology  Semiconductors           Asia     South Korea
# 66    Information Technology  Semiconductors  North America   United States
# 155   Information Technology  Semiconductors  North America   United States
# 157   Information Technology  Semiconductors           Asia          Taiwan
# 353   Information Technology  Semiconductors           Asia     South Korea
# 354   Information Technology  Semiconductors  North America   United States
# 417   Information Technology  Semiconductors  North America   United States
# 592   Information Technology  Semiconductors         Europe     Netherlands
# 681   Information Technology  Semiconductors  North America   United States
# 787   Information Technology  Semiconductors           Asia          Taiwan
# 825   Information Technology  Semiconductors  North America   United States
# 999   Information Technology  Semiconductors           Asia          Taiwan
# 1060  Information Technology  Semiconductors           Asia       Singapore
# 1124  Information Technology  Semiconductors         Europe         Germany
# 1130  Information Technology  Semiconductors         Europe     Netherlands
# 1171  Information Technology  Semiconductors           Asia           Japan
# 1278  Information Technology  Semiconductors  North America   United States
# 1294  Information Technology  Semiconductors           Asia           Japan
# 1328  Information Technology  Semiconductors  North America   United States
# 1347  Information Technology  Semiconductors           Asia          Taiwan
# 1356  Information Technology  Semiconductors  North America   United States
# 1378  Information Technology  Semiconductors  North America   United States
# 1409  Information Technology  Semiconductors         Europe  United Kingdom
# 1471  Information Technology  Semiconductors  North America   United States
# 1565  Information Technology  Semiconductors  North America   United States
# 1596  Information Technology  Semiconductors  North America   United States
# 1761  Information Technology  Semiconductors           Asia          Taiwan
# 1769  Information Technology  Semiconductors         Europe     Switzerland
# 1826  Information Technology  Semiconductors  North America   United States
# 1909  Information Technology  Semiconductors  North America   United States
# 1951  Information Technology  Semiconductors  North America   United States
# 1967  Information Technology  Semiconductors           Asia           Japan
#
#         Headquarters          State                CEO  \
# 17       South Korea            NaN       Oh-Hyun Kwon
# 66        California     California     Brian Krzanich
# 155       California     California  Steven Mollenkopf
# 157           Taiwan            NaN             Te Liu
# 353      South Korea            NaN    Seong-Wook Park
# 354            Idaho          Idaho           D Durcan
# 417            Texas          Texas  Richard Templeton
# 592      Netherlands            NaN      Peter Wennink
# 681       California     California     Gary Dickerson
# 787           Taiwan            NaN          Ming Tsai
# 825       California     California     Scott Mcgregor
# 999           Taiwan            NaN        Chien Chang
# 1060       Singapore            NaN           Hock Tan
# 1124         Germany            NaN     Reinhard Ploss
# 1130     Netherlands            NaN    Richard Clemmer
# 1171           Japan            NaN       Hisao Sakuta
# 1278   Massachusetts  Massachusetts      Vincent Roche
# 1294           Japan            NaN    Tetsuro Higashi
# 1328      California     California     Martin Anstice
# 1347          Taiwan            NaN       Scott Meikle
# 1356   Massachusetts  Massachusetts      David Aldrich
# 1378      California     California     Jen-Hsun Huang
# 1409  United Kingdom            NaN       Simon Segars
# 1471      California     California    Moshe Gavrielov
# 1565      California     California         John Daane
# 1596      California     California       Lothar Maier
# 1761          Taiwan            NaN        Charles Kau
# 1769     Switzerland            NaN      Carlo Bozotti
# 1826      California     California    Richard Wallace
# 1909         Arizona        Arizona       Steve Sanghi
# 1951           Texas          Texas         Gregg Lowe
# 1967           Japan            NaN   Satoshi Sawamura
#
#                                          Forbes Webpage  \
# 17    http://www.forbes.com/companies/samsung-electr...
# 66               http://www.forbes.com/companies/intel/
# 155           http://www.forbes.com/companies/qualcomm/
# 157   http://www.forbes.com/companies/taiwan-semicon...
# 353           http://www.forbes.com/companies/sk-hynix/
# 354   http://www.forbes.com/companies/micron-technol...
# 417   http://www.forbes.com/companies/texas-instrume...
# 592       http://www.forbes.com/companies/asml-holding/
# 681   http://www.forbes.com/companies/applied-materi...
# 787           http://www.forbes.com/companies/mediatek/
# 825           http://www.forbes.com/companies/broadcom/
# 999   http://www.forbes.com/companies/advanced-semic...
# 1060  http://www.forbes.com/companies/avago-technolo...
# 1124  http://www.forbes.com/companies/infineon-techn...
# 1130  http://www.forbes.com/companies/nxp-semiconduc...
# 1171  http://www.forbes.com/companies/renesas-electr...
# 1278    http://www.forbes.com/companies/analog-devices/
# 1294    http://www.forbes.com/companies/tokyo-electron/
# 1328      http://www.forbes.com/companies/lam-research/
# 1347  http://www.forbes.com/companies/inotera-memories/
# 1356  http://www.forbes.com/companies/skyworks-solut...
# 1378            http://www.forbes.com/companies/nvidia/
# 1409      http://www.forbes.com/companies/arm-holdings/
# 1471            http://www.forbes.com/companies/xilinx/
# 1565            http://www.forbes.com/companies/altera/
# 1596  http://www.forbes.com/companies/linear-technol...
# 1761  http://www.forbes.com/companies/nanya-technology/
# 1769  http://www.forbes.com/companies/stmicroelectro...
# 1826        http://www.forbes.com/companies/kla-tencor/
# 1909  http://www.forbes.com/companies/microchip-tech...
# 1951  http://www.forbes.com/companies/freescale-semi...
# 1967              http://www.forbes.com/companies/rohm/
#
#       Profits as % of Assets  Profits as % of Revenue
# 17                  0.104599                 0.111939
# 66                  0.127278                 0.209486
# 155                 0.166429                 0.299028
# 157                 0.184071                 0.345950
# 353                 0.162957                 0.244981
# 354                 0.163448                 0.229703
# 417                 0.156754                 0.212955
# 592                 0.100538                 0.204647
# 681                 0.089268                 0.126285
# 787                 0.137800                 0.217764
# 825                 0.053377                 0.077361
# 999                 0.073675                 0.091957
# 1060                0.044872                 0.092397
# 1124                0.103349                 0.130822
# 1130                0.078195                 0.095449
# 1171                0.076684                 0.071488
# 1278                0.096100                 0.217846
# 1294                0.073111                 0.082509
# 1328                0.088251                 0.147527
# 1347                0.400390                 0.640771
# 1356                0.174992                 0.215432
# 1378                0.087571                 0.134686
# 1409                0.146159                 0.321238
# 1471                0.136236                 0.275783
# 1565                0.083310                 0.244669
# 1596                0.289416                 0.348225
# 1761                0.281137                 0.573720
# 1769                0.014321                 0.017432
# 1826                0.085181                 0.147449
# 1909                0.082329                 0.181736
# 1951                0.076641                 0.054165
# 1967                0.063592                 0.136024

# %% [markdown]
# ## Forbes list
# - 同Industry：1
# - 同Sector：2
# - 有出現在company list：3
# - Company list上有但Forbes沒有：4

# %%
forb_ls =[]

for i in com_ls:
    if (f_data["Company"]==i).any():
        if (f_data[f_data.Company==i]["Industry"]=="Semiconductors").any():
            forb_ls.append(1)
        elif (f_data[f_data.Company==i]["Sector"]=="Information Technology").any():
            forb_ls.append(2)
        else:
            forb_ls.append(3)
    else:
        forb_ls.append(4)

# %%
forb_ls
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %% [markdown]
# ## Company list competitor

# %%
competitor_ls=[4, 3, 4, 1, 1, 1, 2, 1, 1, 1, 1, 1, 1, 2]

# %% [markdown]
# ## 計算NMI

# %%
# (labels_true, labels_pred)
nmi = normalized_mutual_info_score(forb_ls,competitor_ls)
ari = adjusted_rand_score(forb_ls,competitor_ls)

print("nmi: ",nmi)
print("ari: ", ari)
# Out:
# nmi:  0.0
# ari:  0.0

# %% [markdown]
# ## 公司名稱和類別

# %%
competitor_df = pd.DataFrame((zip(com_ls, competitor_ls, forb_ls)), columns = ['company', '2015_competitor', '2015_forb'])

# %%
competitor_df
# Out:
#                                               company  2015_competitor  \
# 0                     Chengdu Qinchuan IoT Technology                4
# 1                        SUZHOU XUANHE IOT TECHNOLOGY                3
# 2         Jiangsu IoT Research and Development Center                4
# 3                     Nanjing Hansense Iot Technology                1
# 4                       Nanjing IoT Sensor Technology                1
# 5           GUANGDONG ABEJ IOT INTELLIGENT TECHNOLOGY                1
# 6                                 Huawei Technologies                2
# 7   SHENZHEN QIANHAI LINGJU INTERNET OF THINGS SCI...                1
# 8              Shenzhen Qianhai Livall IoT Technology                1
# 9        Tianjin Hui Zhiwulian Science And Technology                1
# 10                                           Mangoiot                1
# 11                                Chongqing Liuhe Iot                1
# 12                       Huizhou Sanhe Iot Technology                1
# 13                  Xian Irain IoT Technology Service                2
#
#     2015_forb
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# 5           4
# 6           4
# 7           4
# 8           4
# 9           4
# 10          4
# 11          4
# 12          4
# 13          4

# %%
competitor_df.to_csv("../competitor_df/cpc_cn_2015.csv", index=False)
